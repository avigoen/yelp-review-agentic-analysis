# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import json, os, time, uuid, concurrent.futures as cf
import polars as pl
from concurrent.futures import FIRST_COMPLETED
from typing import Any, Dict, List

from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

from sklearn.metrics import accuracy_score, classification_report

# %%
CHECKPOINT_PATH = "../data/direct_vs_cot_ckpt.parquet"
FINAL_PATH = "../data/direct_vs_cot_ckpt.parquet"   # optional merged output
TEXT_COL = "text"
KEY_COL = "row_id"
MAX_WORKERS = 8
MAX_RETRIES = 3
BASE_BACKOFF = 1.0
FLUSH_EVERY = 100 
IN_FLIGHT_FACTOR = 4               # max queued = MAX_WORKERS * IN_FLIGHT_FACTOR

# %%
df = pl.read_parquet('../data/zero_few_shot_review.parquet')

# %%
# For Serverless API or Managed Compute endpoints
from os import getenv


client = ChatCompletionsClient(
    endpoint="https://portfolio-resource.services.ai.azure.com/models",
    credential=AzureKeyCredential(getenv("AZURE_AI_INFERENCE_KEY")),
    api_version="2024-05-01-preview"
)
model_name = "llama-31_8b"

# %%
REASONING_PROMPT = """You are given a Yelp review.
First explain your reasoning about sentiment and content.
Then, rate the review based on the reasoning.

Rubric:
1 = very negative, would not return
2 = negative with some redeeming detail
3 = mixed/neutral
4 = positive with minor issues
5 = very positive, enthusiastic

Respond in the JSON Format:
{{"stars": <int>, "reason": "<1-3 sentence>"}}

Let's think step by step."""

ZERO_SHOT_USER_TMPL = """Review:
\"\"\"{review_text}\"\"\""""

# %%
schema = {KEY_COL: pl.Int64, "cot_star": pl.Int64, "reasoning": pl.Utf8}

# %%
if os.path.exists(CHECKPOINT_PATH):
    ckpt = pl.read_parquet(CHECKPOINT_PATH).select(
        pl.col(KEY_COL).cast(pl.Int64),
        pl.col("cot_star").cast(pl.Int64),
        pl.col("reasoning").cast(pl.Utf8)
    )
else:
    ckpt = pl.DataFrame({k: pl.Series([], dtype=t) for k, t in schema.items()}, schema=schema)

# %%
seen_ids = set(ckpt[KEY_COL].to_list()) if ckpt.height else set()
work_df = df.filter(~pl.col(KEY_COL).is_in(list(seen_ids))).select([KEY_COL, TEXT_COL])

# %%
print(f"Total rows: {df.height} | Already done: {len(seen_ids)} | Remaining: {work_df.height}")
if work_df.is_empty():
    # (Optional) produce merged DF and exit
    zero_shot_df = df.join(ckpt, on=KEY_COL, how="left")
    zero_shot_df.write_parquet(FINAL_PATH)
    print(f"No remaining rows. Merged output saved to {FINAL_PATH}")
    # You still have zero_shot_df in memory
    # return/exit if in a script
# Out:
# Total rows: 5000 | Already done: 0 | Remaining: 5000

# %%
def get_rating(text: str, system_prompt: str, user: str):
    try:
        response = client.complete(
            messages=[
                SystemMessage(content=system_prompt),
                UserMessage(content=user.format_map({'review_text': text})),
            ],
            max_tokens=128,
            temperature=0.1,
            top_p=0.95,
            model=model_name,
            response_format="json_object"
        )
        output = response.choices[0].message.content
        json_output = json.loads(output)
        return {"cot_star": int(json_output['stars']), "reasoning": json_output['reason']}
    except Exception as ex:
        print(str(ex))
        return {"cot_star": 0, "reasoning": ""}

# %%
def call_with_retry(row_id: int, text: str, cot_system: str) -> Dict[str, Any]:
    for attempt in range(MAX_RETRIES):
        try:
            cot_out = get_rating(text, cot_system, ZERO_SHOT_USER_TMPL)
            cot_out[KEY_COL] = row_id
            return cot_out
        except Exception as e:
            sleep_s = BASE_BACKOFF * (2 ** attempt) * (1 + 0.15 * attempt)
            time.sleep(sleep_s)
            if attempt == MAX_RETRIES - 1:
                attemptt_response = {
                    KEY_COL: row_id,
                    "cot_star": 3,  # fallback neutral
                    "reasoning": f"fallback after error: {type(e).__name__}"
                }
                return attemptt_response

# %%
def atomic_write_parquet(df: pl.DataFrame, path: str):
    tmp = f"{path}.tmp.{uuid.uuid4().hex}.parquet"
    df.write_parquet(tmp)
    os.replace(tmp, path)

# %%
def submit_more(it, ex, futures, in_flight_cap, cot_system):
    """Submit up to (in_flight_cap - len(futures)) new tasks from iterator it."""
    slots = in_flight_cap - len(futures)
    added = 0
    while slots > 0:
        try:
            row = next(it)  # {'row_id':..., 'text':...}
        except StopIteration:
            break
        fut = ex.submit(call_with_retry, int(row[KEY_COL]), str(row[TEXT_COL]),
                        cot_system)
        futures[fut] = row[KEY_COL]
        slots -= 1
        added += 1
    return added

# %%
rows_iter = work_df.iter_rows(named=True)

# %%
buffer = []
completed = 0
in_flight_cap = max(MAX_WORKERS * IN_FLIGHT_FACTOR, MAX_WORKERS)

if work_df.height:
    with cf.ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futures: dict[cf.Future, int] = {}
        submit_more(rows_iter, ex, futures, in_flight_cap, REASONING_PROMPT)  # seed the pool

        # PROCESS EVERYTHING (keep submitting, keep draining)
        while futures:
            done, _pending = cf.wait(set(futures.keys()), return_when=FIRST_COMPLETED)

            # handle all newly-finished futures
            for fut in done:
                rid = futures.pop(fut)  # remove from tracking

                try:
                    cot_res = fut.result()
                except Exception as e:
                    cot_res = {KEY_COL: rid, "cot_star": 3, "reasoning": f"fallback error: {type(e).__name__}"}

                if rid not in seen_ids:
                    buffer.append({
                        KEY_COL: rid,
                        **cot_res
                    })
                    seen_ids.add(rid)
                    completed += 1

                if len(buffer) >= FLUSH_EVERY:
                    buf_df = pl.DataFrame(buffer, schema=schema)
                    ckpt = ckpt.vstack(buf_df)
                    atomic_write_parquet(ckpt, CHECKPOINT_PATH)
                    buffer.clear()
                    print(f"Checkpointed {completed} new rows (total ckpt: {ckpt.height})")

            # top up after draining some
            submit_more(rows_iter, ex, futures, in_flight_cap, REASONING_PROMPT)

        # final flush
        if buffer:
            buf_df = pl.DataFrame(buffer, schema=schema)
            ckpt = ckpt.vstack(buf_df)
            atomic_write_parquet(ckpt, CHECKPOINT_PATH)
            buffer.clear()
            print(f"Final checkpointed. Total in ckpt: {ckpt.height}")

print(f"All done. Newly processed: {completed}. Total in checkpoint: {ckpt.height}.")
# Out:
# Checkpointed 100 new rows (total ckpt: 100)
# Checkpointed 200 new rows (total ckpt: 200)
# Checkpointed 300 new rows (total ckpt: 300)
# Checkpointed 400 new rows (total ckpt: 400)
# Checkpointed 500 new rows (total ckpt: 500)
# Checkpointed 600 new rows (total ckpt: 600)
# Checkpointed 700 new rows (total ckpt: 700)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 800 new rows (total ckpt: 800)
# Invalid \uXXXX escape: line 1 column 276 (char 275)
# Checkpointed 900 new rows (total ckpt: 900)
# Checkpointed 1000 new rows (total ckpt: 1000)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# the JSON object must be str, bytes or bytearray, not NoneType
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "low"
#         }
#     }
# }
# Checkpointed 1100 new rows (total ckpt: 1100)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 1200 new rows (total ckpt: 1200)
# Checkpointed 1300 new rows (total ckpt: 1300)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 1400 new rows (total ckpt: 1400)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 1500 new rows (total ckpt: 1500)
# Checkpointed 1600 new rows (total ckpt: 1600)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "high"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "low"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "low"
#         }
#     }
# }
# Checkpointed 1700 new rows (total ckpt: 1700)
# Checkpointed 1800 new rows (total ckpt: 1800)
# Checkpointed 1900 new rows (total ckpt: 1900)
# Checkpointed 2000 new rows (total ckpt: 2000)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "high"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "low"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 2100 new rows (total ckpt: 2100)
# Expecting ',' delimiter: line 1 column 602 (char 601)
# Checkpointed 2200 new rows (total ckpt: 2200)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "low"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 2300 new rows (total ckpt: 2300)
# Checkpointed 2400 new rows (total ckpt: 2400)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 2500 new rows (total ckpt: 2500)
# Checkpointed 2600 new rows (total ckpt: 2600)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 2700 new rows (total ckpt: 2700)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 2800 new rows (total ckpt: 2800)
# Checkpointed 2900 new rows (total ckpt: 2900)
# Checkpointed 3000 new rows (total ckpt: 3000)
# Checkpointed 3100 new rows (total ckpt: 3100)
# Checkpointed 3200 new rows (total ckpt: 3200)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 3300 new rows (total ckpt: 3300)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 3400 new rows (total ckpt: 3400)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 3500 new rows (total ckpt: 3500)
# Checkpointed 3600 new rows (total ckpt: 3600)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 3700 new rows (total ckpt: 3700)
# Checkpointed 3800 new rows (total ckpt: 3800)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 3900 new rows (total ckpt: 3900)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 4000 new rows (total ckpt: 4000)
# Checkpointed 4100 new rows (total ckpt: 4100)
# Checkpointed 4200 new rows (total ckpt: 4200)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": true,
#             "severity": "high"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 4300 new rows (total ckpt: 4300)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 4400 new rows (total ckpt: 4400)
# Checkpointed 4500 new rows (total ckpt: 4500)
# Unterminated string starting at: line 1 column 24 (char 23)
# Checkpointed 4600 new rows (total ckpt: 4600)
# Checkpointed 4700 new rows (total ckpt: 4700)
# Checkpointed 4800 new rows (total ckpt: 4800)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "sexual": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 4900 new rows (total ckpt: 4900)
# (content_filter) The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Code: content_filter
# Message: The response was filtered due to the prompt triggering Microsoft's content management policy. Please modify your prompt and retry.
# Inner error: {
#     "code": "ResponsibleAIPolicyViolation",
#     "content_filter_result": {
#         "hate": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "self_harm": {
#             "filtered": false,
#             "severity": "safe"
#         },
#         "sexual": {
#             "filtered": true,
#             "severity": "medium"
#         },
#         "violence": {
#             "filtered": false,
#             "severity": "safe"
#         }
#     }
# }
# Checkpointed 5000 new rows (total ckpt: 5000)
# All done. Newly processed: 5000. Total in checkpoint: 5000.

# %%
llm_df = pl.read_parquet(CHECKPOINT_PATH)
llm_df.head()
# Out:
# shape: (5, 3)
# ┌────────┬──────────┬─────────────────────────────────┐
# │ row_id ┆ cot_star ┆ reasoning                       │
# │ ---    ┆ ---      ┆ ---                             │
# │ i64    ┆ i64      ┆ str                             │
# ╞════════╪══════════╪═════════════════════════════════╡
# │ 1      ┆ 5        ┆ The reviewer had a very positi… │
# │ 5      ┆ 5        ┆ The reviewer highly recommends… │
# │ 8      ┆ 4        ┆ The reviewer is generally very… │
# │ 4      ┆ 5        ┆ The reviewer highly recommends… │
# │ 2      ┆ 4        ┆ The reviewer has mixed opinion… │
# └────────┴──────────┴─────────────────────────────────┘

# %%
all_df = df.join(llm_df, on="row_id", how="left")
all_df.head()
# Out:
# shape: (5, 9)
# ┌────────┬───────┬──────────────┬───────────┬───┬──────────┬──────────────┬──────────┬─────────────┐
# │ row_id ┆ label ┆ text         ┆ zero_star ┆ … ┆ few_star ┆ few_explanat ┆ cot_star ┆ reasoning   │
# │ ---    ┆ ---   ┆ ---          ┆ ---       ┆   ┆ ---      ┆ ion          ┆ ---      ┆ ---         │
# │ u32    ┆ i64   ┆ str          ┆ i64       ┆   ┆ i64      ┆ ---          ┆ i64      ┆ str         │
# │        ┆       ┆              ┆           ┆   ┆          ┆ str          ┆          ┆             │
# ╞════════╪═══════╪══════════════╪═══════════╪═══╪══════════╪══════════════╪══════════╪═════════════╡
# │ 0      ┆ 4     ┆ So happy to  ┆ 4         ┆ … ┆ 4        ┆ Good food    ┆ 4        ┆ The         │
# │        ┆       ┆ discover     ┆           ┆   ┆          ┆ and service, ┆          ┆ reviewer is │
# │        ┆       ┆ that Edin…   ┆           ┆   ┆          ┆ but som…     ┆          ┆ very happy  │
# │        ┆       ┆              ┆           ┆   ┆          ┆              ┆          ┆ wit…        │
# │ 1      ┆ 4     ┆ We avoided   ┆ 4         ┆ … ┆ 4        ┆ Friendly     ┆ 5        ┆ The         │
# │        ┆       ┆ the Saturday ┆           ┆   ┆          ┆ service,     ┆          ┆ reviewer    │
# │        ┆       ┆ Badger…      ┆           ┆   ┆          ┆ quick        ┆          ┆ had a very  │
# │        ┆       ┆              ┆           ┆   ┆          ┆ turnov…      ┆          ┆ positi…     │
# │ 2      ┆ 4     ┆ The food is  ┆ 4         ┆ … ┆ 3        ┆ Good food    ┆ 4        ┆ The         │
# │        ┆       ┆ good...but.. ┆           ┆   ┆          ┆ but          ┆          ┆ reviewer    │
# │        ┆       ┆ I thin…      ┆           ┆   ┆          ┆ overpriced,  ┆          ┆ has mixed   │
# │        ┆       ┆              ┆           ┆   ┆          ┆ with…        ┆          ┆ opinion…    │
# │ 3      ┆ 4     ┆ Gets the job ┆ 4         ┆ … ┆ 3        ┆ The reviewer ┆ 4        ┆ The         │
# │        ┆       ┆ done .had a  ┆           ┆   ┆          ┆ found the    ┆          ┆ reviewer    │
# │        ┆       ┆ Weiss…       ┆           ┆   ┆          ┆ beer to…     ┆          ┆ seems to be │
# │        ┆       ┆              ┆           ┆   ┆          ┆              ┆          ┆ gener…      │
# │ 4      ┆ 4     ┆ The          ┆ 5         ┆ … ┆ 5        ┆ A free,      ┆ 5        ┆ The         │
# │        ┆       ┆ Fountains of ┆           ┆   ┆          ┆ beautiful,   ┆          ┆ reviewer    │
# │        ┆       ┆ Bellagio.    ┆           ┆   ┆          ┆ and iconic … ┆          ┆ highly      │
# │        ┆       ┆ Som…         ┆           ┆   ┆          ┆              ┆          ┆ recommends… │
# └────────┴───────┴──────────────┴───────────┴───┴──────────┴──────────────┴──────────┴─────────────┘

# %%
all_df.write_parquet("../data/zero_cot_review.parquet")

# %%
y_test = all_df.select("label").to_numpy()
zero_pred = all_df.select("zero_star").to_numpy()
cot_pred = all_df.select("cot_star").to_numpy()

# %%
print("Accuracy: ", accuracy_score(y_test, zero_pred))
print(classification_report(y_test, zero_pred))
# Out:
# Accuracy:  0.6412
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.68      0.92      0.78      1000
#            2       0.64      0.48      0.54      1000
#            3       0.71      0.41      0.52      1000
#            4       0.56      0.50      0.53      1000
#            5       0.64      0.90      0.75      1000
#
#     accuracy                           0.64      5000
#    macro avg       0.54      0.53      0.52      5000
# weighted avg       0.65      0.64      0.62      5000
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("Accuracy: ", accuracy_score(y_test, cot_pred))
print(classification_report(y_test, cot_pred))
# Out:
# Accuracy:  0.6194
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.68      0.91      0.78      1000
#            2       0.64      0.46      0.53      1000
#            3       0.69      0.36      0.47      1000
#            4       0.50      0.45      0.47      1000
#            5       0.61      0.92      0.74      1000
#
#     accuracy                           0.62      5000
#    macro avg       0.52      0.52      0.50      5000
# weighted avg       0.63      0.62      0.60      5000
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/avinashgoen/projects/Prodigal-Assignment-V2/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Report:
# - Zero-shot COT reasoning reduced the classification than direct zero-shot classification
# - Reason: The reviews have a hidden meaning behind then which cannot be extracted unless we have example to provide as to why a review is positive or negative.
